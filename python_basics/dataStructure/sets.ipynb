# %% [markdown]
# # Sets

# %% [markdown]
# ### sets stores values inside curly braces {} and it does not allow duplicate values.

# %%
set_values = {1,3,4,7}

# %%
type(set_values)
# Out:
# set

# %% [markdown]
# ## Methods in set
# ### add()
# ###

# %%
set_values.add(5)

# %%
set_values
# Out:
# {1, 3, 4, 5, 7}

# %%
set_value2 = set()
for i in range(1,10) :
    set_value2.add(i)
    
set_value2
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8, 9}
