# %% [markdown]
# # Modules & Packages

# %% [markdown]
# ## 1. NumPy (Numerical Python)
# ### is the fundamental open-source package for scientific computing in Python, primarily used for efficient multi-dimensional array processing and mathematical operations.

# %% [markdown]
# ## 2. Pandas
# ### is a Python library used for working with data sets.
#
# ### It has functions for analyzing, cleaning, exploring, and manipulating data.

# %%
import math
math.sqrt(9)
# Out:
# 3.0

# %%
from math import sqrt
sqrt(16)
# Out:
# 4.0

# %%
from math import *
print(pi)
# Out:
# 3.141592653589793

# %%
# r = int(input("Enter Radius"))
r=5
from math import *
area = 2 * pi * (r*r)
print(f'area of circle {area}')
# Out:
# area of circle 157.07963267948966

# %%
# %pip install numpy
# Out:
# Collecting numpy
#   Downloading numpy-2.5.2-cp313-cp313-win_amd64.whl.metadata (6.6 kB)
# Downloading numpy-2.5.2-cp313-cp313-win_amd64.whl (12.5 MB)
#    ---------------------------------------- 0.0/12.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/12.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/12.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/12.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/12.5 MB ? eta -:--:--
#     --------------------------------------- 0.3/12.5 MB ? eta -:--:--
#     --------------------------------------- 0.3/12.5 MB ? eta -:--:--
#     --------------------------------------- 0.3/12.5 MB ? eta -:--:--
#    - -------------------------------------- 0.5/12.5 MB 398.5 kB/s eta 0:00:30
#    - -------------------------------------- 0.5/12.5 MB 398.5 kB/s eta 0:00:30
#    - -------------------------------------- 0.5/12.5 MB 398.5 kB/s eta 0:00:30
#    -- ------------------------------------- 0.8/12.5 MB 424.6 kB/s eta 0:00:28
#    --- ------------------------------------ 1.0/12.5 MB 508.9 kB/s eta 0:00:23
#    --------- ------------------------------ 2.9/12.5 MB 1.5 MB/s eta 0:00:07
#    ----------------- ---------------------- 5.5/12.5 MB 2.7 MB/s eta 0:00:03
#    --------------------- ------------------ 6.6/12.5 MB 2.9 MB/s eta 0:00:03
#    ----------------------- ---------------- 7.3/12.5 MB 3.0 MB/s eta 0:00:02
#    -------------------------- ------------- 8.4/12.5 MB 3.1 MB/s eta 0:00:02
#    ----------------------------- ---------- 9.2/12.5 MB 3.2 MB/s eta 0:00:02
#    ------------------------------ --------- 9.4/12.5 MB 3.1 MB/s eta 0:00:01
#    ------------------------------- -------- 10.0/12.5 MB 3.1 MB/s eta 0:00:01
#    --------------------------------- ------ 10.5/12.5 MB 3.0 MB/s eta 0:00:01
#    ----------------------------------- ---- 11.0/12.5 MB 3.0 MB/s eta 0:00:01
#    ------------------------------------- -- 11.8/12.5 MB 3.0 MB/s eta 0:00:01
#    ---------------------------------------  12.3/12.5 MB 3.0 MB/s eta 0:00:01
#    ---------------------------------------- 12.5/12.5 MB 2.9 MB/s  0:00:05
# Installing collected packages: numpy
# Successfully installed numpy-2.5.2
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import numpy
