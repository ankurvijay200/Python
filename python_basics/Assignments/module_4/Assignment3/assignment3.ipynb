# %% [markdown]
# # Task 1

# %%
def apply_discount(price, discount_percent=5):
    if discount_percent > 60:
        discount_percent = 60
    return price - price * discount_percent / 100

#condition1 
print(apply_discount(1000, 10))

# condition2 if discont percent missing this use 5%
print(apply_discount(500))

# extra if discont more than 60% this will use only 60%
print(apply_discount(600, 70))
# Out:
# 900.0
# 475.0
# 240.0

# %% [markdown]
# # Task 2

# %%
def factorial(n):
    if n < 0:
        return "negative value not allowed"
    elif n == 0 or n == 1:
        return 1
    else:
        result = 1
        for i in range(2, n + 1):
            result *= i
        return result
    
print(factorial(5))
print(factorial(0))
print(factorial(-3))
# Out:
# 120
# 1
# negative value not allowed

# %% [markdown]
# # Task 3

# %%
gst = lambda price : price + (0.18 * price)

print(gst(100))
# Out:
# 118.0

# %% [markdown]
# # Task 4

# %%
prices = [100, 250, 400, 1200, 50]

price_with_gst = list(map(lambda price : price + (0.18 * price), prices))

print(prices) #list1
print(price_with_gst) #list2
# Out:
# [100, 250, 400, 1200, 50]
# [118.0, 295.0, 472.0, 1416.0, 59.0]

# %% [markdown]
# # Task 5

# %%
prices = [100, 250, 400, 1200, 50, 2000, 850]

#condition1
print(list(filter(lambda  price : price > 500, prices)))

#condition2
print(list(filter(lambda  price : price <= 500, prices)))
# Out:
# [1200, 2000, 850]
# [100, 250, 400, 50]

# %% [markdown]
# # Task 6

# %%
process_prices = [100, 500, 900, 50, 750]

def process_prices(prices):
    discounted_prices = list(map(lambda price: int(price - price * 0.10), prices))

    filtered_prices = list(filter(lambda price: price > 300, discounted_prices))

    return discounted_prices, filtered_prices

discounted_prices, filtered_prices = process_prices([100, 500, 900, 50, 750])

print(discounted_prices)
print(filtered_prices)
# Out:
# [90, 450, 810, 45, 675]
# [450, 810, 675]

# %%
def add_price(prices_list, price):
    prices_list.append(price)


def get_average_price(prices_list):
    return sum(prices_list) / len(prices_list)


def get_max_price(prices_list):
    return max(prices_list)


prices = []

while True:
    print("1 → Add price\n2 → Show average price\n3 → Show highest price\nq → Quit")

    choice = input("Enter your choice: ")

    if choice == "1":
        price = float(input("Enter price: "))
        add_price(prices, price)
        print("Price added.")

    elif choice == "2":
        if len(prices) == 0:
            print("No prices available.")
        else:
            print("Average price:", get_average_price(prices))

    elif choice == "3":
        if len(prices) == 0:
            print("No prices available.")
        else:
            print("Highest price:", get_max_price(prices))

    elif choice == "q":
        print("Goodbye!")
        break

    else:
        print("Invalid choice.")
# Out:
# 1 → Add price
# 2 → Show average price
# 3 → Show highest price
# q → Quit
# Price added.
# 1 → Add price
# 2 → Show average price
# 3 → Show highest price
# q → Quit
# Goodbye!
