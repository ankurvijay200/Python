# %% [markdown]
# # Modules & Packages

# %% [markdown]
# ## 1. NumPy (Numerical Python)
# ### is the fundamental open-source package for scientific computing in Python, primarily used for efficient multi-dimensional array processing and mathematical operations.

# %% [markdown]
# ## 2. Pandas
# ### is a Python library used for working with data sets.
#
# ### It has functions for analyzing, cleaning, exploring, and manipulating data.

# %%
import math
math.sqrt(9)
# Out:
# 3.0

# %%
from math import sqrt
sqrt(16)
# Out:
# 4.0

# %%
from math import *
print(pi)
# Out:
# 3.141592653589793

# %%
# r = int(input("Enter Radius"))
r=5
from math import *
area = 2 * pi * (r*r)
print(f'area of circle {area}')
# Out:
# area of circle 157.07963267948966

# %%
# %pip install numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import numpy as np

print(np.__version__)
# Out:
# 2.5.2

# %% [markdown]
# ## numpy

# %%
list1 = [1,2,3,4,5]
arr1 = np.array(list1)
print(arr1)
# Out:
# [1 2 3 4 5]

# %%
type(arr1)
# Out:
# numpy.ndarray

# %%
# %pip install seaborn

# %% [markdown]
# # Create a folder with your chosen package name (e.g., mypackage).
# ### Inside, create an empty or initialization file named __init__.py to signal to Python that the directory is a package. Add your functional code in separate .py files (modules) within this directory.

# %%
from package_folder.mathematics import *

# %%
addition(5,6)
# Out:
# 11

# %%
from package_folder.subpackage_folder.sum import *

# %%
ankurSum1(3,6,1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 ankurSum1(3,6,1)
#
# NameError: name 'ankurSum1' is not defined
