# %% [markdown]
# # Task 1

# %%
from math_utils import *
print(add(5, 3))
print(subtract(5, 3))
print(square(5))
# Out:
# 8
# 2
# 25

# %%
from math_utils import square
print(square(5))
# Out:
# 25

# %% [markdown]
# # Task 2

# %%
from string_utils import *

# return text with each word capital
print(capitalize_words("hello world"))

# return reverse of the string
print(reverse_string("helloworld"))

# return number of words in text
print(word_count("hello world this is a test"))
# Out:
# Hello World
# dlrowolleh
# 6

# %% [markdown]
# # Task 3

# %%
# discount.py
from shop_package.discount import *
print(apply_discount(100, 10))
print(flat_discount(70))
# Out:
# 10.0
# 20

# %%
prices = [100,200,250,500,700]

from shop_package.billing import *
total = calculate_total(prices)
print(f'Total is : {total}')

print(f'Amount after tax : {apply_tax(total)}')
# Out:
# Total is : 1750
# Amount after tax : 1837.5

# %% [markdown]
# # Task 4

# %%
import shop_package.discount as disc
from shop_package.billing import calculate_total

print(disc.apply_discount(100, 10))
print(disc.flat_discount(70))

calculate_total = calculate_total([100,200,300,400,500])
print(calculate_total)

print(apply_tax(calculate_total))
# Out:
# 10
# 20
# 1500
# 1575.0
