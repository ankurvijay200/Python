# %% [markdown]
# # Data Structures in Python

# %% [markdown]
# ### used for storing the data in the structured formate so that we can access the data and along with that we can perform all the operation with these data structure that we can perform in case of database as we like crud (create, read, update, delete) operations.

# %% [markdown]
# # Types Of Data Structure
#  ## 1. List
#  ## 2. Tuple
#  ## 3. Set
#  ## 4. Dictionary
